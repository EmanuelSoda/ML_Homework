# %% [markdown]
# <table width=100%>
# <tr>
#     <td><h1 style="text-align: left; font-size:300%;">
#        Protein Expression in Mice with Down Syndrome
#     </h1></td>
#     <td width="20%">
#     <div style="text-align: right">
#     <b> Homework Machine Learning 2020</b>
#     <br> Emanuel Michele Soda <br>
#     <a href="emanuelmichele.soda@mail.polimi.it">emanuelmichele.soda@mail.polimi.it</a><br>
#     </div>
#     </td>
#     <td width="111px">
#         <a href="https://www.polimi.it">
#         <img align="right", width="95px" src='https://labolfattometrico.chem.polimi.it/wp-content/uploads/2019/12/POLIMI-corretto-3-1024x1024.jpg' alt=''>
#         </a>
#     </td>
# </tr>
# </table>

# %% [markdown]
# ## Importing Packages

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import sklearn as sk
from sklearn import preprocessing
from sklearn.decomposition import PCA
import matplotlib.cm as cm
import matplotlib.colors as mcolors
from sklearn.feature_selection import SelectKBest   #ricordali di toglierli nel caso non servono 
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.feature_selection import SelectFromModel

# %% [markdown]
# ## Loding data

# %%
train = pd.read_csv("Data/train.csv")
print(train.shape)
train
# Out:
# (367, 77)
#      DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N   pBRAF_N  \
# 0    0.650511  1.158653  0.580172  2.230388  3.179675  0.533686  0.440101
# 1    0.365907  0.651296  0.810468  2.597217  4.131603  0.537554  0.249235
# 2    0.260145  0.397996  0.229522  2.643311  4.303648  0.268394  0.050916
# 3    0.239489  0.271240  0.766816  1.872419  2.424971  0.322269  0.386791
# 4    0.617112  0.751737  0.050685  2.356175  3.494138  0.506875  0.310644
# ..        ...       ...       ...       ...       ...       ...       ...
# 362  0.265617  0.318703  0.062552  2.190572  3.028526  0.314935  0.293579
# 363  0.371998  0.683835  0.088809  2.264053  3.901498  0.308142  0.256376
# 364  0.853106  1.048825  0.422033  2.037549  3.480993  0.402487  0.125134
# 365  0.523508  0.846670  0.777588  2.493568  4.117986  0.229136  0.193073
# 366  0.268021  0.148416  0.495106  1.907162  2.712791  0.457461  0.083159
#
#      pCAMKII_N   pCREB_N    pELK_N  ...     SHH_N     BAD_N     pS6_N  \
# 0     5.033898  0.200985  1.589221  ...  0.047287  0.337121  0.203356
# 1     6.099538  0.226362  1.700578  ...  0.521112  0.419544  0.231619
# 2     3.130455  0.273792  2.534531  ...  0.047407  0.053130  0.096325
# 3     2.351832  0.034265  0.472725  ...  0.273651  0.162382  0.234056
# 4     3.855825  0.309879  1.033428  ...  0.172488  0.014086  0.191145
# ..         ...       ...       ...  ...       ...       ...       ...
# 362   5.647761  0.194538  1.293860  ...  0.281070  0.169755  0.070476
# 363   4.628201  0.045254  1.405705  ...  0.380423  0.346237  0.256601
# 364   2.216711  0.116000  2.158211  ...  0.364075  0.099125  0.040736
# 365   2.650853  0.001629  1.536754  ...  0.220932  0.191266  0.049275
# 366   4.814792  0.345000  1.308648  ...  0.304764  0.108574  0.683065
#
#       pCFOS_N     SYP_N  H3AcK18_N    EGR1_N  H3MeK4_N    CaNA_N   class
# 0    0.191360  0.590874   0.112145  0.110109  0.160637  1.329248  t-CS-m
# 1    0.393897  0.252572   0.352687  0.085545  0.328537  1.008023  t-SC-s
# 2    0.257402  0.246015   0.203979  0.039188  0.008315  1.193634  c-SC-s
# 3    0.180657  0.351388   0.103896  0.302341  0.166020  0.689970  c-CS-m
# 4    0.149622  0.310434   0.151685  0.180055  0.383039  1.737274  t-CS-s
# ..        ...       ...        ...       ...       ...       ...     ...
# 362  0.246973  0.420950   0.144801  0.198893  0.198080  1.132259  c-SC-m
# 363  0.158367  0.139080   0.422385  0.115629  0.389457  1.104580  c-SC-m
# 364  0.530906  0.379040   0.046529  0.075847  0.068273  1.243315  t-CS-m
# 365  0.063009  0.541193   0.335438  0.218873  0.081170  1.161350  t-CS-s
# 366  0.180120  0.399666   0.121613  0.049929  0.157915  1.067880  c-SC-m
#
# [367 rows x 77 columns]

# %% [markdown]
# ## Preliminary Analysis

# %% [markdown]
# ### Missing value check

# %%
# check if there are null value in the dataset
if train.isnull().sum().sum() == 0:
    print('No null value')
else:
    print('Null value found')
# Out:
# No null value

# %%
#Normalization (NON SO SE SERVE)

#train

#from sklearn.preprocessing import StandardScaler
#std = StandardScaler#()
#train = std.fit_transform(train.loc[:, train.columns != 'class']).append(train['class'])

#train

# %%
# pairplot che non vanno perché ne sono troppi

#sns.set(style="ticks", color_codes=True)

#prova = sns.pairplot(train)

# %% [markdown]
# ### Get Class Labels

# %%
labelClass = train['class']
labelClass
le = preprocessing.LabelEncoder()
labelEncoded = le.fit(labelClass)
#le.classes_
codedLabel = le.transform(labelClass)
#train['class'] = le.transform(labelClass)
#train['class']
#le.inverse_transform(train['class'])

#train = train.drop(columns = ['class'], axis=1)
#train
# Out:
# 0      t-CS-m
# 1      t-SC-s
# 2      c-SC-s
# 3      c-CS-m
# 4      t-CS-s
#         ...
# 362    c-SC-m
# 363    c-SC-m
# 364    t-CS-m
# 365    t-CS-s
# 366    c-SC-m
# Name: class, Length: 367, dtype: object

# %%
train = train.drop(columns = ['class'], axis=1)
train
# Out:
#      DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N   pBRAF_N  \
# 0    0.650511  1.158653  0.580172  2.230388  3.179675  0.533686  0.440101
# 1    0.365907  0.651296  0.810468  2.597217  4.131603  0.537554  0.249235
# 2    0.260145  0.397996  0.229522  2.643311  4.303648  0.268394  0.050916
# 3    0.239489  0.271240  0.766816  1.872419  2.424971  0.322269  0.386791
# 4    0.617112  0.751737  0.050685  2.356175  3.494138  0.506875  0.310644
# ..        ...       ...       ...       ...       ...       ...       ...
# 362  0.265617  0.318703  0.062552  2.190572  3.028526  0.314935  0.293579
# 363  0.371998  0.683835  0.088809  2.264053  3.901498  0.308142  0.256376
# 364  0.853106  1.048825  0.422033  2.037549  3.480993  0.402487  0.125134
# 365  0.523508  0.846670  0.777588  2.493568  4.117986  0.229136  0.193073
# 366  0.268021  0.148416  0.495106  1.907162  2.712791  0.457461  0.083159
#
#      pCAMKII_N   pCREB_N    pELK_N  ...  pGSK3B_Tyr216_N     SHH_N     BAD_N  \
# 0     5.033898  0.200985  1.589221  ...         0.957219  0.047287  0.337121
# 1     6.099538  0.226362  1.700578  ...         0.611896  0.521112  0.419544
# 2     3.130455  0.273792  2.534531  ...         1.062417  0.047407  0.053130
# 3     2.351832  0.034265  0.472725  ...         0.700040  0.273651  0.162382
# 4     3.855825  0.309879  1.033428  ...         0.413610  0.172488  0.014086
# ..         ...       ...       ...  ...              ...       ...       ...
# 362   5.647761  0.194538  1.293860  ...         0.581550  0.281070  0.169755
# 363   4.628201  0.045254  1.405705  ...         1.002144  0.380423  0.346237
# 364   2.216711  0.116000  2.158211  ...         0.773044  0.364075  0.099125
# 365   2.650853  0.001629  1.536754  ...         1.258303  0.220932  0.191266
# 366   4.814792  0.345000  1.308648  ...         0.841879  0.304764  0.108574
#
#         pS6_N   pCFOS_N     SYP_N  H3AcK18_N    EGR1_N  H3MeK4_N    CaNA_N
# 0    0.203356  0.191360  0.590874   0.112145  0.110109  0.160637  1.329248
# 1    0.231619  0.393897  0.252572   0.352687  0.085545  0.328537  1.008023
# 2    0.096325  0.257402  0.246015   0.203979  0.039188  0.008315  1.193634
# 3    0.234056  0.180657  0.351388   0.103896  0.302341  0.166020  0.689970
# 4    0.191145  0.149622  0.310434   0.151685  0.180055  0.383039  1.737274
# ..        ...       ...       ...        ...       ...       ...       ...
# 362  0.070476  0.246973  0.420950   0.144801  0.198893  0.198080  1.132259
# 363  0.256601  0.158367  0.139080   0.422385  0.115629  0.389457  1.104580
# 364  0.040736  0.530906  0.379040   0.046529  0.075847  0.068273  1.243315
# 365  0.049275  0.063009  0.541193   0.335438  0.218873  0.081170  1.161350
# 366  0.683065  0.180120  0.399666   0.121613  0.049929  0.157915  1.067880
#
# [367 rows x 76 columns]

# %% [markdown]
# ## Feature Selection

# %%
# scelgo il modello per ridurre le features prov: CON LINEAR REGRESSION

sel = SelectFromModel(LinearRegression())

# %%
#lo alleno
sel.fit(train, codedLabel)
# Out:
# SelectFromModel(estimator=LinearRegression(copy_X=True, fit_intercept=True,
#                                            n_jobs=None, normalize=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
# mi dice quali sono le features che sono state scelte
#sel.get_support()

# %%
# mi dice i coef di ogni feature
#sel.estimator_.coef_

# %%
# così mostro proprio il nome della features
features_linear = train.columns[sel.get_support()]
features_linear
# Out:
# Index(['DYRK1A_N', 'pCREB_N', 'pERK_N', 'BRAF_N', 'SOD1_N', 'MTOR_N',
#        'DSCR1_N', 'AMPKA_N', 'NUMB_N', 'BAX_N', 'Tau_N', 'GFAP_N', 'SHH_N'],
#       dtype='object')

# %%
# quindi il nostro nuovo train è così ottenuto
train_trasform_linear = sel.transform(train)
train_trasform_linear.shape
train.shape
# Out:
# (367, 13)
# (367, 76)

# %%
# Scelgo il modello per ridurre le features scelgo: Lasso <--- o almeno così dovrebbe essere con l1 penalty 
sel = SelectFromModel(LogisticRegression(penalty= 'l1', solver = 'liblinear', C = 0.1)) # più C è piccolo più riduce le features 
sel.fit(train, codedLabel)
sel.get_support()
features_lasso = train.columns[sel.get_support()]
features_lasso
train_trasform_lasso = sel.transform(train)
train_trasform_lasso.shape
train.shape
# Out:
# SelectFromModel(estimator=LogisticRegression(C=0.1, class_weight=None,
#                                              dual=False, fit_intercept=True,
#                                              intercept_scaling=1, l1_ratio=None,
#                                              max_iter=100, multi_class='auto',
#                                              n_jobs=None, penalty='l1',
#                                              random_state=None,
#                                              solver='liblinear', tol=0.0001,
#                                              verbose=0, warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)
# array([False, False, False, False,  True, False, False,  True, False,
#         True,  True, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False,  True])
# Index(['NR2A_N', 'pCAMKII_N', 'pELK_N', 'pERK_N', 'pPKCAB_N', 'ERK_N',
#        'SOD1_N', 'pPKCG_N', 'PSD95_N', 'CaNA_N'],
#       dtype='object')
# (367, 10)
# (367, 76)

# %% [markdown]
# ### Data visualization

# %% [markdown]
# Calculating the correlation matrix to show the correlation between the gene

# %%
plt.figure(figsize = (12,10))
corrMat = train.corr()
type(corrMat)
#corrMat[corrMat.gt(0.8) ][]
#corrMat[corrMat > 0,6 & corrMat < 1]
#print(corrMat.to_numpy()[:, -1])
sns.heatmap(corrMat)
# Out:
# pandas.core.frame.DataFrame

# %%
# calcola le Principal Component e la percentuale di variazione espressa da queste
def principalComponent(data, n_comp):
    #scaled_Train = scale(train.drop(['class'], axis = 1))
    pca = PCA(n_comp) 
    return pca.fit_transform(data), np.round(pca.explained_variance_ratio_ * 100, decimals = 1)


principalComp, per_var = principalComponent(train.loc[:, train.columns != 'class'], min(train.loc[:, train.columns != 'class'].shape))

principalComp.shape
# Out:
# (367, 76)

# %%
plot_labels = ['PC' + str(s) for s in range(1, len(per_var) + 1)]
plt.figure(figsize = (44, 10))
plt.bar(x = range(1, len(per_var) + 1), height = per_var, tick_label = plot_labels)
plt.ylabel('Percentage of Explained Variance')
plt.xlabel('Principal Component')
plt.title('Plot 1')
plt.show()
# Out:
# <BarContainer object of 76 artists>
# Text(0, 0.5, 'Percentage of Explained Variance')
# Text(0.5, 0, 'Principal Component')
# Text(0.5, 1.0, 'Plot 1')

# %%
#per ora ho ignorato " _ " la percentuale di varianza espressa
pc_plot, _ = principalComponent(train.loc[:, train.columns != 'class'], 3)
pc_plot = pd.DataFrame(pc_plot, columns = plot_labels[0 : 3])
unique_labelClass = np.unique(labelEn.transform(labelClass)) 
nlabels = len(unique_labelClass)
fig = plt.figure(figsize = (15, 10))
ax = fig.add_subplot(111, projection = '3d')
col = ('tab10' if nlabels <= 10 else  ('tab20' if nlabels <= 20 else 'hsv'))
cmap = plt.cm.get_cmap('viridis', 8)
smap = cm.ScalarMappable(norm = mcolors.Normalize(unique_labelClass.min(), unique_labelClass .max() + 1),   cmap=cmap)
ax.scatter(xs = pc_plot.PC1, ys = pc_plot.PC2, zs = pc_plot.PC3, marker = '.', s = 200, 
           c = labelEn.transform(labelClass), cmap = cmap)
plt.colorbar(mappable = smap, label = 'Label', ticks = range(nlabels))

# %% [markdown]
# ## Clustering

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

linkage()  # qui da errore perché devo continuare
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-90555fbd84bd> in <module>
#       1 from scipy.cluster.hierarchy import dendrogram, linkage
#       2
# ----> 3 linkage()  # qui da errore perché devo continuare
#
# TypeError: linkage() missing 1 required positional argument: 'y'

# %%
# ?linkage

# %%
test = pd.read_csv("Data/test.csv")
test.head()

# %% [markdown]
# #####
